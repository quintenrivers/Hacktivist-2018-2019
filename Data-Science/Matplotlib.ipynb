# %% [markdown]
# # Hacktivist Session: Matplotlib

# %% [markdown]
# ## Intro to Matplotlib
# Matplotlib is a data visualization library used to show 2D and 3D graphs and is meant to be on par with MatLab’s graphing.
# > Matplotlib is highly customizable. Matplotlib is still widely used but it is very old and newer libraries such as Seaborn, especially when used with Cufflinks, are generally easier to use.

# %% [markdown]
# ## Installation and Usage
# Matplotlib should already come with the Anaconda distribution. If not:
# ```
# conda install matplotlib
# pip install matplotlib
# ```
# To use matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline                
# inline lets you see the plots in the notebook

# %% [markdown]
# ## Basic Plotting

# %%
x = np.linspace(0, 5, 11)
y = x ** 2

plt.plot(x, y, 'r')             # 'r' is the color red
plt.xlabel('X Axis Title Here')
plt.ylabel('Y Axis Title Here')
plt.title('String Title Here')
plt.show()

# %% [markdown]
# ## Multiple Plots

# %%
plt.subplot(1,2,1)     # plt.subplot(nrows, ncols, plot_number)
plt.plot(x, y, 'r--')
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');

# %% [markdown]
# ## Object-Oriented Plotting
# The preferred method of plotting

# %%
# Create Figure (empty canvas)
fig = plt.figure()                        #creates the object

# Add set of axes to figure
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # left,bottom,width,height (range 0 to 1)

# Plot on that set of axes
axes.plot(x, y, 'b')                      #actually plots (x,y)
axes.set_xlabel('Set X Label')
axes.set_ylabel('Set y Label')
axes.set_title('Set Title')
# Out:
# Text(0.5,1,'Set Title')

# %% [markdown]
# ## Special Plot Types
# These are useful but I mostly use Seaborn to do this

# %%
plt.scatter(x,y) # scatter

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data) # histogram
# Out:
# (array([13.,  5., 13.,  9., 12., 12.,  8., 11.,  5., 12.]),
#  array([ 23., 120., 217., 314., 411., 508., 605., 702., 799., 896., 993.]),
#  <a list of 10 Patch objects>)

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# rectangular box plot
plt.boxplot(data,vert=True,patch_artist=True) # boxplot
# Out:
# {'boxes': [<matplotlib.patches.PathPatch at 0x1190eed68>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1190f35f8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1190fb2b0>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x1190f3e48>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x1190eefd0>,
# ...
#   <matplotlib.lines.Line2D at 0x11910d9b0>]}
